# %%
import pandas as pd

# %% [markdown]
# # Einlesen der Daten

# %%
data = pd.read_csv("2007-2016-Homelessnewss-USA.csv")
data
# Out:
#            Year State CoC Number               CoC Name  \
# 0      1/1/2007    AK     AK-500          Anchorage CoC
# 1      1/1/2007    AK     AK-500          Anchorage CoC
# 2      1/1/2007    AK     AK-500          Anchorage CoC
# 3      1/1/2007    AK     AK-500          Anchorage CoC
# 4      1/1/2007    AK     AK-500          Anchorage CoC
# ...         ...   ...        ...                    ...
# 86524  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86525  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86526  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86527  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86528  1/1/2016    WY     WY-500  Wyoming Statewide CoC
#
#                                                 Measures Count
# 0                       Chronically Homeless Individuals   224
# 1                                   Homeless Individuals   696
# 2                            Homeless People in Families   278
# ...

# %% [markdown]
# # Daten ausgeben

# %%
print(data)
# Out:
#            Year State CoC Number               CoC Name  \
# 0      1/1/2007    AK     AK-500          Anchorage CoC
# 1      1/1/2007    AK     AK-500          Anchorage CoC
# 2      1/1/2007    AK     AK-500          Anchorage CoC
# 3      1/1/2007    AK     AK-500          Anchorage CoC
# 4      1/1/2007    AK     AK-500          Anchorage CoC
# ...         ...   ...        ...                    ...
# 86524  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86525  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86526  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86527  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86528  1/1/2016    WY     WY-500  Wyoming Statewide CoC
#
#                                                 Measures Count
# 0                       Chronically Homeless Individuals   224
# 1                                   Homeless Individuals   696
# 2                            Homeless People in Families   278
# ...

# %% [markdown]
# # Die ersten 5 Zeilen des Datensatzes ausgeben

# %%
data.head()
# Out:
#        Year State CoC Number       CoC Name  \
# 0  1/1/2007    AK     AK-500  Anchorage CoC
# 1  1/1/2007    AK     AK-500  Anchorage CoC
# 2  1/1/2007    AK     AK-500  Anchorage CoC
# 3  1/1/2007    AK     AK-500  Anchorage CoC
# 4  1/1/2007    AK     AK-500  Anchorage CoC
#
#                                      Measures Count
# 0            Chronically Homeless Individuals   224
# 1                        Homeless Individuals   696
# 2                 Homeless People in Families   278
# 3  Sheltered Chronically Homeless Individuals   187
# 4                          Sheltered Homeless   842

# %% [markdown]
# # Die letzten 5 Zeilen des Datensatzes ausgeben

# %%
data.tail()
# Out:
#            Year State CoC Number               CoC Name  \
# 86524  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86525  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86526  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86527  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86528  1/1/2016    WY     WY-500  Wyoming Statewide CoC
#
#                                                 Measures Count
# 86524  Unsheltered Homeless Unaccompanied Youth (Unde...     7
# 86525                      Unsheltered Homeless Veterans    31
# 86526             Unsheltered Parenting Youth (Under 25)     3
# 86527              Unsheltered Parenting Youth Age 18-24     3
# 86528               Unsheltered Parenting Youth Under 18     0

# %% [markdown]
# # Informationen ueber das Dataframe ausgeben

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86529 entries, 0 to 86528
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        86529 non-null  object
#  1   State       86529 non-null  object
#  2   CoC Number  86529 non-null  object
#  3   CoC Name    86529 non-null  object
#  4   Measures    86529 non-null  object
#  5   Count       86529 non-null  object
# dtypes: object(6)
# memory usage: 4.0+ MB

# %% [markdown]
# # Anzahl Zeilen und Spalten vom Dataframe ausgeben

# %%
data.shape
# Out:
# (86529, 6)

# %%
row = data.shape[0]
coloum = data.shape[1]
print("Number of rows {0}, number of coloumns {1}".format(row, coloum))
# Out:
# Number of rows 86529, number of coloumns 6

# %% [markdown]
# # Die 5 Summary Number ausgeben

# %%
data.describe()
# Out:
#             Year  State CoC Number       CoC Name  \
# count      86529  86529      86529          86529
# unique        10     54        414            414
# top     1/1/2015     CA     AK-500  Anchorage CoC
# freq       16926   8946        216            216
#
#                                 Measures  Count
# count                              86529  86529
# unique                                42   3608
# top     Chronically Homeless Individuals      0
# freq                                3999  12209

# %% [markdown]
# # Nummerierung der Indexe ausgeben

# %%
data.index
# Out:
# RangeIndex(start=0, stop=86529, step=1)

# %% [markdown]
# # Alle Spaltenname ausgeben

# %%
data.columns
# Out:
# Index(['Year', 'State', 'CoC Number', 'CoC Name', 'Measures', 'Count'], dtype='object')

# %% [markdown]
# # Alle Werte vom DF ausgeben

# %%
data.values
# Out:
# array([['1/1/2007', 'AK', 'AK-500', 'Anchorage CoC',
#         'Chronically Homeless Individuals', '224'],
#        ['1/1/2007', 'AK', 'AK-500', 'Anchorage CoC',
#         'Homeless Individuals', '696'],
#        ['1/1/2007', 'AK', 'AK-500', 'Anchorage CoC',
#         'Homeless People in Families', '278'],
#        ...,
#        ['1/1/2016', 'WY', 'WY-500', 'Wyoming Statewide CoC',
#         'Unsheltered Parenting Youth (Under 25)', '3'],
#        ['1/1/2016', 'WY', 'WY-500', 'Wyoming Statewide CoC',
#         'Unsheltered Parenting Youth Age 18-24', '3'],
#        ['1/1/2016', 'WY', 'WY-500', 'Wyoming Statewide CoC',
#         'Unsheltered Parenting Youth Under 18', '0']], dtype=object)

# %% [markdown]
# # Dataframe sortieren

# %%
data.columns
# Out:
# Index(['Year', 'State', 'CoC Number', 'CoC Name', 'Measures', 'Count'], dtype='object')

# %%
data.sort_values('Year', ascending=True)
# Out:
#            Year State CoC Number                                    CoC Name  \
# 0      1/1/2007    AK     AK-500                               Anchorage CoC
# 3219   1/1/2007    NV     NV-502                 Nevada Balance of State CoC
# 3218   1/1/2007    NV     NV-502                 Nevada Balance of State CoC
# 3217   1/1/2007    NV     NV-502                 Nevada Balance of State CoC
# 3216   1/1/2007    NV     NV-502                 Nevada Balance of State CoC
# ...         ...   ...        ...                                         ...
# 75277  1/1/2016    IN     IN-500  South Bend/Mishawaka/St. Joseph County CoC
# 75278  1/1/2016    IN     IN-500  South Bend/Mishawaka/St. Joseph County CoC
# 75279  1/1/2016    IN     IN-500  South Bend/Mishawaka/St. Joseph County CoC
# 75281  1/1/2016    IN     IN-500  South Bend/Mishawaka/St. Joseph County CoC
# 86528  1/1/2016    WY     WY-500                       Wyoming Statewide CoC
#
# ...

# %%
data.sort_values(['Year', 'Count'], ascending=[True,False])
# Out:
#            Year State CoC Number                                CoC Name  \
# 284    1/1/2007    CA     CA-501                       San Francisco CoC
# 270    1/1/2007    CA     CA-500  San Jose/Santa Clara City & County CoC
# 3055   1/1/2007    NJ     NJ-507      New Brunswick/Middlesex County CoC
# 3689   1/1/2007    OK     OK-502                       Oklahoma City CoC
# 2489   1/1/2007    MN     MN-500         Minneapolis/Hennepin County CoC
# ...         ...   ...        ...                                     ...
# 86485  1/1/2016    WV     WV-508      West Virginia Balance of State CoC
# 86486  1/1/2016    WV     WV-508      West Virginia Balance of State CoC
# 86499  1/1/2016    WY     WY-500                   Wyoming Statewide CoC
# 86513  1/1/2016    WY     WY-500                   Wyoming Statewide CoC
# 86528  1/1/2016    WY     WY-500                   Wyoming Statewide CoC
#
#                                            Measures Count
# ...

# %% [markdown]
# # Spalte auswaehlen

# %%
data['State']
# Out:
# 0        AK
# 1        AK
# 2        AK
# 3        AK
# 4        AK
#          ..
# 86524    WY
# 86525    WY
# 86526    WY
# 86527    WY
# 86528    WY
# Name: State, Length: 86529, dtype: object

# %% [markdown]
# # Mehrere Spalten auswaehlen

# %%
col_subset = ["Year", "State"]
data[col_subset]
# Out:
#            Year State
# 0      1/1/2007    AK
# 1      1/1/2007    AK
# 2      1/1/2007    AK
# 3      1/1/2007    AK
# 4      1/1/2007    AK
# ...         ...   ...
# 86524  1/1/2016    WY
# 86525  1/1/2016    WY
# 86526  1/1/2016    WY
# 86527  1/1/2016    WY
# 86528  1/1/2016    WY
#
# [86529 rows x 2 columns]

# %%
data[["Year","Count"]]
# Out:
#            Year Count
# 0      1/1/2007   224
# 1      1/1/2007   696
# 2      1/1/2007   278
# 3      1/1/2007   187
# 4      1/1/2007   842
# ...         ...   ...
# 86524  1/1/2016     7
# 86525  1/1/2016    31
# 86526  1/1/2016     3
# 86527  1/1/2016     3
# 86528  1/1/2016     0
#
# [86529 rows x 2 columns]

# %%
data["State"].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Spalte nach einem bestimmten Wert auswaehlen

# %%
data[data["Year"] == "1/1/2007"]
# Out:
#           Year State CoC Number               CoC Name  \
# 0     1/1/2007    AK     AK-500          Anchorage CoC
# 1     1/1/2007    AK     AK-500          Anchorage CoC
# 2     1/1/2007    AK     AK-500          Anchorage CoC
# 3     1/1/2007    AK     AK-500          Anchorage CoC
# 4     1/1/2007    AK     AK-500          Anchorage CoC
# ...        ...   ...        ...                    ...
# 4819  1/1/2007    WY     WY-500  Wyoming Statewide CoC
# 4820  1/1/2007    WY     WY-500  Wyoming Statewide CoC
# 4821  1/1/2007    WY     WY-500  Wyoming Statewide CoC
# 4822  1/1/2007    WY     WY-500  Wyoming Statewide CoC
# 4823  1/1/2007    WY     WY-500  Wyoming Statewide CoC
#
#                                           Measures Count
# 0                 Chronically Homeless Individuals   224
# 1                             Homeless Individuals   696
# 2                      Homeless People in Families   278
# 3       Sheltered Chronically Homeless Individuals   187
# ...

# %%
data[data["Year"].isin(["1/1/2007"])]
# Out:
#           Year State CoC Number               CoC Name  \
# 0     1/1/2007    AK     AK-500          Anchorage CoC
# 1     1/1/2007    AK     AK-500          Anchorage CoC
# 2     1/1/2007    AK     AK-500          Anchorage CoC
# 3     1/1/2007    AK     AK-500          Anchorage CoC
# 4     1/1/2007    AK     AK-500          Anchorage CoC
# ...        ...   ...        ...                    ...
# 4819  1/1/2007    WY     WY-500  Wyoming Statewide CoC
# 4820  1/1/2007    WY     WY-500  Wyoming Statewide CoC
# 4821  1/1/2007    WY     WY-500  Wyoming Statewide CoC
# 4822  1/1/2007    WY     WY-500  Wyoming Statewide CoC
# 4823  1/1/2007    WY     WY-500  Wyoming Statewide CoC
#
#                                           Measures Count
# 0                 Chronically Homeless Individuals   224
# 1                             Homeless Individuals   696
# 2                      Homeless People in Families   278
# 3       Sheltered Chronically Homeless Individuals   187
# ...

# %%
is_in_CA = data["State"].isin(["CA", "AK"])
is_in_CA
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 86524    False
# 86525    False
# 86526    False
# 86527    False
# 86528    False
# Name: State, Length: 86529, dtype: bool

# %%
data[is_in_CA]
# Out:
#            Year State CoC Number                         CoC Name  \
# 0      1/1/2007    AK     AK-500                    Anchorage CoC
# 1      1/1/2007    AK     AK-500                    Anchorage CoC
# 2      1/1/2007    AK     AK-500                    Anchorage CoC
# 3      1/1/2007    AK     AK-500                    Anchorage CoC
# 4      1/1/2007    AK     AK-500                    Anchorage CoC
# ...         ...   ...        ...                              ...
# 72286  1/1/2016    CA     CA-615  Inyo, Mono, Alpine Counties CoC
# 72287  1/1/2016    CA     CA-615  Inyo, Mono, Alpine Counties CoC
# 72288  1/1/2016    CA     CA-615  Inyo, Mono, Alpine Counties CoC
# 72289  1/1/2016    CA     CA-615  Inyo, Mono, Alpine Counties CoC
# 72290  1/1/2016    CA     CA-615  Inyo, Mono, Alpine Counties CoC
#
#                                                 Measures Count
# 0                       Chronically Homeless Individuals   224
# ...

# %%
ca_state = data["State"] == "CA"
data[ca_state]
# Out:
#            Year State CoC Number                                CoC Name  \
# 264    1/1/2007    CA     CA-500  San Jose/Santa Clara City & County CoC
# 265    1/1/2007    CA     CA-500  San Jose/Santa Clara City & County CoC
# 266    1/1/2007    CA     CA-500  San Jose/Santa Clara City & County CoC
# 267    1/1/2007    CA     CA-500  San Jose/Santa Clara City & County CoC
# 268    1/1/2007    CA     CA-500  San Jose/Santa Clara City & County CoC
# ...         ...   ...        ...                                     ...
# 72286  1/1/2016    CA     CA-615         Inyo, Mono, Alpine Counties CoC
# 72287  1/1/2016    CA     CA-615         Inyo, Mono, Alpine Counties CoC
# 72288  1/1/2016    CA     CA-615         Inyo, Mono, Alpine Counties CoC
# 72289  1/1/2016    CA     CA-615         Inyo, Mono, Alpine Counties CoC
# 72290  1/1/2016    CA     CA-615         Inyo, Mono, Alpine Counties CoC
#
#                                                 Measures  Count
# ...

# %% [markdown]
# # Spalte hinzufuegen (Mutieren/Transformieren)

# %%
data2 = pd.read_csv("homelessness.csv", index_col="Unnamed: 0")

# %%
data2.head(7)
# Out:
#                region        state  individuals  family_members  state_pop
# 0  East South Central      Alabama       2570.0           864.0    4887681
# 1             Pacific       Alaska       1434.0           582.0     735139
# 2            Mountain      Arizona       7259.0          2606.0    7158024
# 3  West South Central     Arkansas       2280.0           432.0    3009733
# 4             Pacific   California     109008.0         20964.0   39461588
# 5            Mountain     Colorado       7607.0          3250.0    5691287
# 6         New England  Connecticut       2280.0          1696.0    3571520

# %% [markdown]
# # Spalte hinzufuegen

# %%
# Spalte hinzufuegen
data2["individuals/state_pop"] = data2["individuals"] / data2["state_pop"]

# Spalte wird gefiltert
data_filter = data2[data2["individuals/state_pop"] >= 0.001014]

# Spalte wird sortiert, Absteigend
data_filter = data_filter.sort_values("individuals/state_pop", ascending=False)

# Vom DF nur die gewuenschten selektieren
data_filter[["individuals","state_pop","individuals/state_pop"]].head(10)
# Out:
#     individuals  state_pop  individuals/state_pop
# 8        3770.0     701547               0.005374
# 11       4131.0    1420593               0.002908
# 4      109008.0   39461588               0.002762
# 37      11139.0    4181886               0.002664
# 28       7058.0    3027341               0.002331
# 47      16424.0    7523869               0.002183
# 32      39827.0   19530351               0.002039
# 1        1434.0     735139               0.001951
# 5        7607.0    5691287               0.001337
# 45        780.0     624358               0.001249

# %%
data2.sort_values("individuals/state_pop")
# Out:
#                 region                 state  individuals  family_members  \
# 24  East South Central           Mississippi       1024.0           328.0
# 46      South Atlantic              Virginia       3928.0          2047.0
# 49  East North Central             Wisconsin       2740.0          2167.0
# 16  West North Central                Kansas       1443.0           773.0
# 22  East North Central              Michigan       5209.0          3142.0
# 0   East South Central               Alabama       2570.0           864.0
# 13  East North Central              Illinois       6752.0          3891.0
# 15  West North Central                  Iowa       1711.0          1038.0
# 18  West South Central             Louisiana       2540.0           519.0
# 14  East North Central               Indiana       3776.0          1482.0
# 48      South Atlantic         West Virginia       1021.0           222.0
# 35  East North Central                  Ohio       6929.0          3320.0
# ...

# %%
# Einlesen der Daten und Zuweisung einer Variabel
homelessness = pd.read_csv("homelessness.csv", index_col="Unnamed: 0")

# Zusaetliche Spalte hinzugefuegt
homelessness["indiv_per_10k"] = 10000 * homelessness["individuals"] / homelessness["state_pop"]
homelessness.head()

# Datensatz filtern
high_homelessness = homelessness[homelessness["indiv_per_10k"] > 20]

# Datensatz sortieren nach indiv_per_10k
high_homelessness_srt = high_homelessness.sort_values("indiv_per_10k", ascending = False)

# Vom Datensatz nur die gewuenschten Spalten auswaehlen
high_homelessness_srt[["indiv_per_10k", "state"]]
# Out:
#     indiv_per_10k                 state
# 8       53.738381  District of Columbia
# 11      29.079406                Hawaii
# 4       27.623825            California
# 37      26.636307                Oregon
# 28      23.314189                Nevada
# 47      21.829195            Washington
# 32      20.392363              New York

# %%
homelessness
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama       2570.0           864.0
# 1              Pacific                Alaska       1434.0           582.0
# 2             Mountain               Arizona       7259.0          2606.0
# 3   West South Central              Arkansas       2280.0           432.0
# 4              Pacific            California     109008.0         20964.0
# 5             Mountain              Colorado       7607.0          3250.0
# 6          New England           Connecticut       2280.0          1696.0
# 7       South Atlantic              Delaware        708.0           374.0
# 8       South Atlantic  District of Columbia       3770.0          3134.0
# 9       South Atlantic               Florida      21443.0          9587.0
# 10      South Atlantic               Georgia       6943.0          2556.0
# 11             Pacific                Hawaii       4131.0          2399.0
# ...
